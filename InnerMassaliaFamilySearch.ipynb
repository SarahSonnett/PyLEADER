# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import random

# %%
infile = '/Users/ssonnett/Desktop/work/MBA_SFDs/Massalia_InnerFamily_IDs.txt'

innerids = np.genfromtxt(infile,unpack=True,dtype=str)

# %%
famdir = '/Users/ssonnett/Desktop/work/MBA_SFDs/Fam20_data_allsky_4band_p1bs_psd_w3/'

famfiles = os.listdir(famdir)

# %%
print(famfiles[0:10])
# Out:
# ['29142.obs', '60542.obs', '37817.obs', '35806.obs', '64334.obs', '56635.obs', '95131.obs', '15296.obs', '73113.obs', '74668.obs']

# %%
foundIDs = [fle.split('.')[0] for fle in famfiles if fle.startswith('Nofilter') is False]

# %%
print(foundIDs)
# Out:
# ['29142', '60542', '37817', '35806', '64334', '56635', '95131', '15296', '73113', '74668', '55665', '30162', '79238', '56542', '40478', '55868', '27965', '13418', '38138', '26306', '75038', '35408', '29236', '30613', '18809', '57893', '9884', '33681', '46756', '16983', '54184', '72235', '35142', '52442', '10102', '18760', '14760', '35221', '94410', '28767', '42421', '4734', '21385', '33597', '38207', '63773', '79073', '40369', '20264', '29081', '73991', '96706', '12176', '74595', '57364', '69265', '19972', '69067', '96676', '59238', '75088', '55199', '12401', '74948', '31596', '37118', '43841', '43060', '8452', '8446', '11519', '7760', '39915', '12414', '48281', '10983', '90167', '57409', '2946', '37128', '20440', '31388', '85836', '22860', '75086', '15798', '66560', '42415', '14928', '66428', '95013', '56066', '38813', '53902', '17173', '35885', '34392', '54853', '36608', '91313', '35843', '68617', '40414', '94916', '44920', '64400', '32849', '12409', '73912', '28719', '25361', '592
# ...

# %%
innerIDs = [ID for ID in foundIDs if ID in innerids]

# %%
print(len(innerids))
# Out:
# 5786
